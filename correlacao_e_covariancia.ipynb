# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickzyz/correlacao_e_covariancia/blob/main/correlacao_e_covariancia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

alturas = np.array([160, 170, 175, 163, 175])
# peak-to-peak
print(alturas)
amplitude = np.ptp(alturas)
print(amplitude)
# amplitude = maior valor - menor valor
# Out:
# [160 170 175 163 175]
# 15

# %%
# desvio padrão
media_alturas = np.mean(alturas)
print(media_alturas)

# calculo de desvio padrão
desvio_padrao = np.std(alturas, ddof=1)
print(desvio_padrao)
# Out:
# 168.6
# 6.877499545619759

# %%
# covariância positivo
# duas coisas crescem ou decrescem ao mesmo tempo

# covariância negativa
# quando uma variavel cresce e a outra decres

# covariância zero
# nada muda

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

dados_equipamento = {
    'consumo' : [10,20,30,40,50,60,70,80],
    'temperatura' : [90,89,89,91,90,91,90,90]
}

# transformar esses dados para o pandas ler
df_dados = pd.DataFrame(dados_equipamento)

# vamos fazer o calculo da covariância
#criar uma base para a covariancia
cov_matrix = df_dados.cov()
print(f'a covariância foi {cov_matrix.iloc[0,1]}')

# corr - função para correlação
correlacao_matrix =df_dados.corr()

print(correlacao_matrix)

# gerar um grafico para essas correlações
sns.scatterplot(x='consumo', y='temperatura', data=df_dados)
plt.title('grafico de correlação')
plt.show()
# Out:
# a covariância foi 7.142857142857142
#               consumo  temperatura
# consumo      1.000000     0.385758
# temperatura  0.385758     1.000000
